# %%
# %matplotlib inline
import numpy as np
import pylab

# %%
import urllib
urllib.request.urlretrieve('https://cs.unc.edu/Courses/comp116-f17/media/fpb.jpg', filename='fpb.jpg')
# Out:
# ('fpb.jpg', <http.client.HTTPMessage at 0x109861eb8>)

# %%
fpb = pylab.imread('fpb.jpg')
print(fpb.shape)
# Out:
# (165, 305, 3)

# %%
def show(im):
    pylab.imshow(im, cmap=pylab.gray(), interpolation='none')
    
show(fpb)

# %%
fpb[1,:,:]
# Out:
# array([[202, 218, 208],
#        [202, 218, 208],
#        [203, 219, 209],
#        [204, 220, 210],
#        [205, 221, 211],
#        [206, 222, 212],
#        [207, 223, 213],
#        [208, 224, 214],
#        [206, 222, 212],
#        [206, 222, 212],
#        [206, 222, 212],
#        [207, 223, 213],
#        [207, 223, 213],
#        [208, 224, 214],
#        [208, 224, 214],
#        [208, 224, 214],
#        [207, 227, 216],
#        [205, 225, 214],
#        [205, 225, 214],
#        [206, 226, 215],
#        [206, 226, 215],
#        [201, 221, 210],
#        [191, 211, 200],
#        [182, 202, 191],
#        [184, 204, 193],
#        [183, 203, 192],
#        [183, 203, 192],
#        [183, 203, 192],
#        [182, 202, 191],
#        [182, 202, 191],
#        [182, 202, 191],
#        [182, 202, 191],
#        [177, 206, 176],
#        [181, 206, 185],
#        [179, 198, 192],
#        [185, 196, 198],
#        [192, 196, 197],
#        [189, 187, 175],
#        [124, 117,  88],
#        [ 99,  84,  43],
#        [102,  81,  36],
#        [122,  92,  54],
#        [137, 100,  73],
#        [ 91,  48,  29],
#        [ 81,  35,  12],
#        [ 95,  49,  15],
#        [111,  65,  15],
#        [115,  71,  10],
#        [115,  75,  24],
#        [115,  72,  21],
#        [123,  73,  22],
#        [125,  69,  18],
#        [128,  70,  22],
#        [137,  83,  37],
#        [120,  72,  32],
#        [ 75,  39,   3],
#        [ 67,  44,  12],
#        [ 68,  52,  26],
#        [ 88,  76,  50],
#        [166, 150, 125],
#        [218, 192, 165],
#        [216, 179, 150],
#        [185, 136, 104],
#        [145,  90,  59],
#        [114, 104, 102],
#        [ 90,  90,  66],
#        [ 41,  52,  20],
#        [ 40,  58,  44],
#        [ 74,  98,  98],
#        [ 96, 124, 110],
#        [ 42,  72,  36],
#        [ 88, 112,  78],
#        [200, 214, 201],
#        [197, 209, 199],
#        [178, 194, 167],
#        [142, 169, 134],
#        [115, 156, 140],
#        [113, 168, 173],
#        [123, 193, 195],
#        [129, 210, 193],
#        [120, 184, 194],
#        [131, 193, 190],
#        [138, 196, 174],
#        [147, 191, 156],
#        [147, 172, 140],
#        [125, 138, 118],
#        [113, 129, 126],
#        [123, 154, 159],
#        [130, 173, 179],
#        [119, 155, 153],
#        [137, 139, 126],
#        [151, 109,  87],
#        [175,  96,  66],
#        [195, 103,  66],
#        [190, 103,  58],
#        [194, 118,  69],
#        [183, 122,  77],
#        [177, 126,  81],
#        [179, 150, 106],
#        [167, 164, 119],
#        [146, 169, 125],
#        [ 73, 118,  75],
#        [ 78, 139,  98],
#        [ 85, 151, 113],
#        [ 89, 155, 117],
#        [147, 205, 165],
#        [161, 208, 164],
#        [124, 157, 110],
#        [134, 157, 103],
#        [151, 162, 104],
#        [100, 106,  42],
#        [ 61,  63,   0],
#        [ 54,  53,   9],
#        [ 38,  36,  15],
#        [ 58,  55,  46],
#        [132, 136, 113],
#        [136, 146, 111],
#        [ 40,  52,  28],
#        [ 95, 108, 101],
#        [152, 170, 156],
#        [152, 178, 139],
#        [151, 180, 136],
#        [166, 191, 170],
#        [182, 207, 204],
#        [149, 174, 168],
#        [116, 142, 129],
#        [111, 135, 139],
#        [ 83, 102, 132],
#        [112, 146, 171],
#        [134, 177, 196],
#        [129, 185, 198],
#        [121, 188, 194],
#        [112, 186, 185],
#        [117, 188, 182],
#        [143, 200, 193],
#        [151, 186, 180],
#        [109, 120, 116],
#        [132, 121, 119],
#        [129, 104, 100],
#        [145, 116, 108],
#        [141, 119, 105],
#        [151, 140, 118],
#        [206, 209, 180],
#        [213, 224, 190],
#        [211, 230, 211],
#        [202, 223, 206],
#        [195, 216, 201],
#        [195, 217, 205],
#        [199, 222, 212],
#        [202, 225, 219],
#        [200, 223, 217],
#        [198, 219, 214],
#        [194, 214, 205],
#        [188, 204, 193],
#        [185, 198, 181],
#        [195, 203, 182],
#        [210, 214, 189],
#        [216, 217, 186],
#        [208, 205, 170],
#        [196, 192, 155],
#        [204, 195,  66],
#        [203, 196,  82],
#        [186, 179,  91],
#        [152, 147,  91],
#        [124, 123,  95],
#        [117, 119, 114],
#        [119, 128, 133],
#        [121, 136, 141],
#        [125, 146, 147],
#        [124, 149, 143],
#        [137, 164, 155],
#        [142, 167, 163],
#        [138, 161, 167],
#        [ 94, 112, 134],
#        [ 91, 105, 140],
#        [118, 129, 174],
#        [114, 142, 166],
#        [124, 150, 185],
#        [129, 152, 202],
#        [130, 152, 210],
#        [123, 144, 199],
#        [117, 141, 179],
#        [ 81, 107, 120],
#        [ 86, 113, 104],
#        [ 80, 110,  86],
#        [ 86, 114,  91],
#        [100, 124, 110],
#        [140, 163, 157],
#        [106, 126, 124],
#        [113, 134, 125],
#        [101, 124, 106],
#        [ 88, 111,  85],
#        [180, 191, 187],
#        [219, 230, 224],
#        [212, 224, 212],
#        [207, 220, 202],
#        [209, 223, 197],
#        [188, 203, 170],
#        [178, 194, 155],
#        [178, 195, 151],
#        [184, 201, 157],
#        [197, 214, 172],
#        [198, 214, 177],
#        [189, 204, 173],
#        [198, 212, 187],
#        [217, 230, 212],
#        [213, 225, 211],
#        [193, 205, 193],
#        [202, 221, 191],
#        [197, 212, 191],
#        [204, 217, 208],
#        [213, 223, 224],
#        [210, 221, 217],
#        [212, 223, 209],
#        [209, 222, 194],
#        [194, 210, 171],
#        [150, 166, 129],
#        [125, 141, 115],
#        [140, 157, 151],
#        [150, 167, 175],
#        [153, 171, 185],
#        [150, 173, 179],
#        [166, 193, 188],
#        [155, 183, 169],
#        [136, 162, 163],
#        [140, 164, 190],
#        [134, 155, 200],
#        [127, 142, 173],
#        [144, 154, 146],
#        [204, 209, 168],
#        [209, 213, 162],
#        [204, 213, 170],
#        [208, 215, 173],
#        [230, 217, 164],
#        [216, 166,  97],
#        [178,  81,  12],
#        [201,  72,  15],
#        [217,  81,  31],
#        [225, 106,  50],
#        [227, 124,  57],
#        [207, 118,  52],
#        [197,  99,  36],
#        [201,  92,  35],
#        [207,  89,  41],
#        [211,  92,  52],
#        [210, 103,  71],
#        [190, 109,  82],
#        [240, 194, 171],
#        [227, 219, 200],
#        [201, 226, 207],
#        [179, 223, 206],
#        [192, 243, 226],
#        [197, 240, 223],
#        [190, 218, 203],
#        [208, 221, 204],
#        [219, 220, 206],
#        [207, 221, 222],
#        [216, 231, 228],
#        [214, 230, 220],
#        [216, 234, 218],
#        [213, 232, 212],
#        [212, 234, 213],
#        [206, 229, 213],
#        [165, 188, 182],
#        [146, 169, 175],
#        [132, 154, 175],
#        [ 99, 122, 154],
#        [ 71,  94, 135],
#        [ 83, 105, 152],
#        [103, 126, 176],
#        [ 88, 111, 163],
#        [147, 170, 222],
#        [223, 222, 217],
#        [219, 219, 211],
#        [216, 217, 209],
#        [217, 220, 211],
#        [219, 225, 215],
#        [220, 228, 217],
#        [215, 226, 212],
#        [211, 223, 209],
#        [168, 182, 167],
#        [106, 123, 105],
#        [ 94, 115,  96],
#        [111, 134, 114],
#        [129, 154, 132],
#        [155, 180, 158],
#        [172, 200, 177],
#        [192, 220, 197],
#        [171, 215, 228],
#        [168, 212, 223],
#        [165, 209, 212],
#        [173, 214, 210],
#        [174, 207, 196],
#        [205, 230, 211],
#        [ 61,  73,  51],
#        [ 34,  34,  10],
#        [ 40,  28,   6],
#        [ 49,  28,   9],
#        [ 46,  20,   7],
#        [ 46,  24,  13],
#        [ 75,  58,  51],
#        [237, 227, 225],
#        [237, 236, 234],
#        [235, 236, 238],
#        [236, 235, 241]], dtype=uint8)

# %%
show(fpb[:,:,1])

# %%
pylab.plot(fpb[80,:,1])

# %%
fpbg=fpb.copy()
fpbg[:,:,0]=0
fpbg[:,:,2]=0
show(fpbg)

# %%
fpb.shape
# Out:
# (165, 305, 3)

# %%
g=fpb[:,:,1]
show(g)

# %%
show(g[::2,::2])

# %%
show(g[::8,::8])

# %%
show(g[::10,::10])

# %%
np.max(g)
# Out:
# 254

# %%
np.min(g)
# Out:
# 0

# %%
gs= g/254.0
show(gs)

# %%
np.max(gs)
# Out:
# 1.0

# %%
gb=gs> 0.55
show(gb)

# %%
show(gs>.25)

# %%
show(gs>.5)

# %%
gb.dtype
# Out:
# dtype('bool')

# %%
show(np.random.random((165,305)))

# %%
show(gs +0.1*(np.random.random((165,305))-0.5)>0.5)

# %%
show(gs +0.3*(np.random.random((165,305))-0.5)>0.5)

# %%
show(gs +0.5*(np.random.random((165,305))-0.5)>0.5)

# %%
show(gs +0.8*(np.random.random((165,305))-0.5)>0.5)
