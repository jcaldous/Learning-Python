# %%
# np.argmin and mp.argmax find the index of the min/ max respectfully

# %%
# %matplotlib inline
import numpy as np
import pylab

# %% [markdown]
# This is a little helper function to display an image. This is a good example of why we write functions. I don't want to have to type all of these arguments every time I want to see an image

# %%
def show(im):
    '''Display an image with square pixels'''
    pylab.imshow(im, cmap=pylab.gray(), interpolation='none')

# %% [markdown]
# First we can make a small image that is all black. The type bool has values True (1) and False (0). When we display it as an image, 0 appears black and 1 appears white. Thus this first image is all black.

# %%
im1 = np.zeros((20,20), dtype=bool)
show(im1)

# %%
im1[10,10]=1
show(im1)

# %%
im1[10,:]=1
show(im1)

# %%
im1[:,10]=1
show(im1)

# %%
im1[9,9]=1
show(im1)

# %%
im1[:,:]=1
im1[5,5]=0
im1[5,15]=0
im1[5:10,10]=0
im1[15,5:16]=0
im1[2,5:16]=0
show(im1)

# %%
res=np.zeros_like(im1)
show(res)

# %%
res[:,:-5]=im1[:,5:]
show (res)

# %%
res2=np.zeros_like(im1)
res2[:,5:]=im1[:,:-5]
show(res2)

# %%
im1[:,:]=1
im1[5,5]=0
im1[5,15]=0
im1[5:10,10]=0
im1[15,5:16]=0
im1[2,5:16]=0
im1[14,4]=0
im1[14,16]=0
im1[15,4]=0
im1[15,16]=0
im1[13,4]=0
im1[13,16]=0
im1[16,8:14]=0
im1[17,9:13]=0
im1[18,10:12]=0
im1[10,10:13]=0
show(im1)

# %%
def sl(im,amt):
    res=np.zeros_like(im)
    res[:,:-amt]=im[:,amt:]
    return res
show(sl(im1,2))

# %%
show(-LI)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e4ee83bb4662> in <module>()
# ----> 1 show(-LI)
#
# NameError: name 'show' is not defined
